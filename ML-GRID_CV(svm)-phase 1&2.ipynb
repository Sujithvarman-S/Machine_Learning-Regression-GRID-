# %%
import pandas as pd    #library used for processing table or excel,csv file....

# %%
dataset=pd.read_csv("insurance_pred.csv") #data collection
#dataset

# %%
dataset = pd.get_dummies(dataset,drop_first=True)   #data preprocessing...
#dataset

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[[ 'charges']]                                          #splitting input and output

# %%
from sklearn.model_selection import GridSearchCV  # it will automatically do train_test_split and model creation steps in traditional method.
from sklearn.svm import SVR
param_grid={"kernel":["poly","sigmoid","linear","rbf"],"C":[0.1,0.100]}
                                                 #here we are using dictionary({}) to store hyper tunned parameter.
grid= GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.1, 0.1],
#                          'kernel': ['poly', 'sigmoid', 'linear', 'rbf']},
#              verbose=3)

# %%
results=grid.cv_results_
#print(result)
table= pd.DataFrame.from_dict(results)  #here we are using dictionary extension because we stored every hyper tunning parameter in dictionary above..
table                 #it will show the every combination of hyper tunned parameter and best model which gridcv find above , in a table here..


# it also used to compare this algorithm with different algorith using rank_test_score which is the best algorithm for this 
#given dataset and problem statement....
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.099594      0.015105         0.016379        0.002277      0.1
# 1       0.109143      0.003095         0.022610        0.001476      0.1
# 2       0.072194      0.006601         0.014235        0.001241      0.1
# 3       0.091571      0.002617         0.041740        0.002043      0.1
# 4       0.088231      0.005904         0.016587        0.001200      0.1
# 5       0.107261      0.004817         0.021661        0.004199      0.1
# 6       0.085083      0.003910         0.015676        0.000959      0.1
# 7       0.079348      0.015419         0.020969        0.002715      0.1
#
#   param_kernel                           params  split0_test_score  \
# 0         poly     {'C': 0.1, 'kernel': 'poly'}          -0.112857
# 1      sigmoid  {'C': 0.1, 'kernel': 'sigmoid'}          -0.115314
# 2       linear   {'C': 0.1, 'kernel': 'linear'}          -0.156586
# 3          rbf      {'C': 0.1, 'kernel': 'rbf'}          -0.115326
# 4         poly     {'C': 0.1, 'kernel': 'poly'}          -0.112857
# 5      sigmoid  {'C': 0.1, 'kernel': 'sigmoid'}          -0.115314
# 6       linear   {'C': 0.1, 'kernel': 'linear'}          -0.156586
# 7          rbf      {'C': 0.1, 'kernel': 'rbf'}          -0.115326
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -0.105099          -0.077609          -0.104969          -0.108333
# 1          -0.113654          -0.081616          -0.106034          -0.107251
# 2          -0.102518          -0.117799          -0.140213          -0.216269
# 3          -0.113152          -0.081428          -0.105862          -0.107303
# 4          -0.105099          -0.077609          -0.104969          -0.108333
# 5          -0.113654          -0.081616          -0.106034          -0.107251
# 6          -0.102518          -0.117799          -0.140213          -0.216269
# 7          -0.113152          -0.081428          -0.105862          -0.107303
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -0.101773        0.012418                1
# 1        -0.104774        0.012116                5
# 2        -0.146677        0.039413                7
# 3        -0.104614        0.012116                3
# 4        -0.101773        0.012418                1
# 5        -0.104774        0.012116                5
# 6        -0.146677        0.039413                7
# 7        -0.104614        0.012116                3

# %%
future_prediction= grid.predict([[19,27.900,0,False,True]])
print("future_prediction:{}".format(future_prediction))  # this is == to r2_score in traditional method.
# Out:
# future_prediction:[9104.06297773]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
import pickle
filename="finalized_GRID_svm.sav"
pickle.dump(grid,open(filename,"wb")) # saving our best model by a new filename.

# %%
###PHASE-2

# %%
import pickle
loaded_model= pickle.load(open("finalized_GRID_svm.sav","rb"))#loading our model using saved file name
result= loaded_model.predict([[78,29.99,74,1,0]])
result                 #you can use this model by using this particular code for any future prediction in new file...
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([9995.73167001])
