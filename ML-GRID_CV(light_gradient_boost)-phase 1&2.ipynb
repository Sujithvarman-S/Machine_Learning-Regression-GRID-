# %%
import pandas as pd    #library used for processing table or excel,csv file....

# %%
dataset=pd.read_csv("insurance_pred.csv") #data collection
#dataset

# %%
dataset = pd.get_dummies(dataset,drop_first=True)   #data preprocessing...
#dataset

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[[ 'charges']]                                          #splitting input and output

# %%
from sklearn.model_selection import GridSearchCV  # it will automatically do train_test_split and model creation steps in traditional method.
from lightgbm import LGBMRegressor
param_grid={'learning_rate': [0.1,0.100],
    'num_leaves': [31,100],
    'max_depth': [5,10],
    'n_estimators': [50,100],
    'min_data_in_leaf': [50,100],
    'subsample': [0.6,1.0],
    'colsample_bytree': [0.6,1.0]}
                                                 #here we are using dictionary({}) to store hyper tunned parameter.
grid= GridSearchCV(LGBMRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000044 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 313
# [LightGBM] [Info] Number of data points in the train set: 1338, number of used features: 5
# [LightGBM] [Info] Start training from score 13270.422260
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
results=grid.cv_results_
#print(result)
table= pd.DataFrame.from_dict(results)  #here we are using dictionary extension because we stored every hyper tunning parameter in dictionary above..
table                 #it will show the every combination of hyper tunned parameter and best model which gridcv find above , in a table here..


# it also used to compare this algorithm with different algorith using rank_test_score which is the best algorithm for this 
#given dataset and problem statement....
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.584593      0.145284         0.009797        0.004361
# 1         0.529155      0.087559         0.011432        0.004979
# 2         0.413389      0.177313         0.006609        0.002460
# 3         0.235730      0.017536         0.006211        0.001163
# 4         0.335141      0.016433         0.005689        0.000484
# ..             ...           ...              ...             ...
# 123       0.143534      0.007442         0.004904        0.000665
# 124       0.227069      0.017017         0.004903        0.000494
# 125       0.225322      0.002562         0.005208        0.000510
# 126       0.202125      0.016191         0.004609        0.000375
# 127       0.167008      0.009423         0.004706        0.000401
#
#      param_colsample_bytree  param_learning_rate  param_max_depth  \
# 0                       0.6                  0.1                5
# ...

# %%
future_prediction= grid.predict([[19,27.900,0,False,True]])
print("future_prediction:{}".format(future_prediction))  # this is == to r2_score in traditional method.
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# future_prediction:[18504.77257809]

# %%
import pickle
filename="finalized_GRID_light_gradient_boost.sav"
pickle.dump(grid,open(filename,"wb")) # saving our best model by a new filename.

# %%
###PHASE-2

# %%
import pickle
loaded_model= pickle.load(open("finalized_GRID_light_gradient_boost.sav","rb"))#loading our model using saved file name
result= loaded_model.predict([[78,29.99,74,1,0]])
result                 #you can use this model by using this particular code for any future prediction in new file...
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# array([16580.94016745])
