# %%
####PHASE-1

# %%
import pandas as pd    #library used for processing table or excel,csv file....

# %%
dataset=pd.read_csv("insurance_pred.csv") # data collection
#dataset

# %%
dataset=pd.get_dummies(dataset,drop_first=True) #data preprocessing
#dataset

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']] #splitting input and output...
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV   # it will automatically do train_test_split and model creation steps in traditional method.
from sklearn.tree import DecisionTreeRegressor
param_grid = {"criterion":["absolute_error","squared_error","friedman_mse","poisson"],"splitter":["random","best"]}
                                            #here we are using dictionary({}) to store hyper tunned parameter.
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True ,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'squared_error',
#                                        'friedman_mse', 'poisson'],
#                          'splitter': ['random', 'best']},
#              verbose=3)

# %%
results=grid.cv_results_
#print(result)
table= pd.DataFrame.from_dict(results)  #here we are using dictionary extension because we stored every hyper tunning parameter in dictionary above..
table                 #it will show the every combination of hyper tunned parameter and best model which gridcv find above , in a table here..

# it also used to compare this algorithm with different algorith using rank_test_score which is the best algorithm for this 
#given dataset and problem statement....
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.041065      0.004186         0.005974        0.000694
# 1       0.050080      0.003449         0.005228        0.001990
# 2       0.008405      0.002126         0.003574        0.001877
# 3       0.010839      0.000182         0.005860        0.000743
# 4       0.009075      0.000475         0.004425        0.000569
# 5       0.010947      0.000770         0.004404        0.000694
# 6       0.012872      0.002841         0.004476        0.001174
# 7       0.012017      0.001589         0.003887        0.000258
#
#   param_criterion param_splitter  \
# 0  absolute_error         random
# 1  absolute_error           best
# 2   squared_error         random
# 3   squared_error           best
# 4    friedman_mse         random
# 5    friedman_mse           best
# 6         poisson         random
# 7         poisson           best
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'absolute_error', 'splitter': 'r...           0.688495
# 1  {'criterion': 'absolute_error', 'splitter': 'b...           0.736107
# 2  {'criterion': 'squared_error', 'splitter': 'ra...           0.676981
# 3  {'criterion': 'squared_error', 'splitter': 'be...           0.712757
# 4  {'criterion': 'friedman_mse', 'splitter': 'ran...           0.720705
# 5  {'criterion': 'friedman_mse', 'splitter': 'best'}           0.722563
# 6     {'criterion': 'poisson', 'splitter': 'random'}           0.536621
# 7       {'criterion': 'poisson', 'splitter': 'best'}           0.752254
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.648605           0.673801           0.699696           0.754496
# 1           0.597529           0.704987           0.709009           0.744661
# 2           0.554992           0.721041           0.693476           0.750884
# 3           0.648656           0.722890           0.735137           0.675582
# 4           0.608631           0.713888           0.702563           0.700212
# 5           0.644865           0.733302           0.744402           0.678317
# 6           0.603165           0.749741           0.724247           0.698878
# 7           0.646896           0.762692           0.709884           0.703914
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.693018        0.035175                5
# 1         0.698459        0.052712                4
# 2         0.679475        0.067120                7
# 3         0.699004        0.032090                3
# 4         0.689200        0.040971                6
# 5         0.704690        0.037389                2
# 6         0.662531        0.080141                8
# 7         0.715128        0.041109                1

# %%
future_prediction = grid.predict([[19,27.900,0,False,True]])
print("future_prediction:{}".format(future_prediction))   # this is == to r2_score in traditional method.
# Out:
# future_prediction:[16884.924]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle
filename="finalized_GRID_decision_tree.sav"  # saving our best model by a new filename.
pickle.dump(grid,open(filename,"wb"))

# %%
###PHASE-2

# %%
import pickle
loaded_model=pickle.load(open("finalized_GRID_decision_tree.sav","rb"))   #loading our model using saved file name.
result=loaded_model.predict([[78,29.99,74,1,0]])    # our own input...
result     #you can use this model by using this particular code for any future prediction in new file...
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([36580.28216])
