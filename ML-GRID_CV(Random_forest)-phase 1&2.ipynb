# %%
##PHASE-1

# %%
import pandas as pd        #library used for processing table or excel,csv datasets....

# %%
dataset=pd.read_csv("insurance_pred.csv")    # data collection
#dataset

# %%
dataset=pd.get_dummies(dataset,drop_first=True) #data preprocessing
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]          #spliting input and output

# %%
from sklearn.model_selection import GridSearchCV      # it will automatically do train_test_split and model creation steps in traditional method.
from sklearn.ensemble import RandomForestRegressor
params_grid = {"criterion":["squared_error","absolute_error","friedman_mse","poisson"]}
                                            #here we are using dictionary({}) to store hyper tunned parameter.
grid = GridSearchCV(RandomForestRegressor(),params_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson']},
#              verbose=3)

# %%
results=grid.cv_results_
#print(result)
table= pd.DataFrame.from_dict(results)  #here we are using dictionary extension because we stored every hyper tunning parameter in dictionary above..
table                 #it will show the every combination of hyper tunned parameter and best model which gridcv find above , in a table here..


# it also used to compare this algorithm with different algorith using rank_test_score which is the best algorithm for this 
#given dataset and problem statement....
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.401159      0.004001         0.017821        0.001241
# 1       1.672669      0.010087         0.012476        0.001993
# 2       0.397449      0.005344         0.015534        0.000586
# 3       0.527367      0.050418         0.011517        0.001555
#
#   param_criterion                           params  split0_test_score  \
# 0   squared_error   {'criterion': 'squared_error'}           0.847551
# 1  absolute_error  {'criterion': 'absolute_error'}           0.845622
# 2    friedman_mse    {'criterion': 'friedman_mse'}           0.846794
# 3         poisson         {'criterion': 'poisson'}           0.847174
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.772159           0.852660           0.818851           0.836980
# 1           0.767510           0.847135           0.822659           0.835960
# 2           0.771407           0.856168           0.820273           0.840004
# 3           0.779418           0.852941           0.819922           0.834891
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.825640        0.029138                3
# 1         0.823777        0.029457                4
# 2         0.826929        0.030158                1
# 3         0.826869        0.026292                2

# %%
future_prediction = grid.predict([[19,27.900,0,False,True]])
print("future_prediction:{}".format(future_prediction))          # this is == to r2_score in traditional method.
# Out:
# future_prediction:[16971.8278915]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle
filename="finalized_Grid_random_forest.sav"   # saving our best model by a new filename.
pickle.dump(grid,open(filename,"wb"))

# %%
##PHASE-2

# %%
import pickle
loaded_model=pickle.load(open("finalized_Grid_random_forest.sav","rb")) #loading our model using saved file name.
result=loaded_model.predict([[78,29.99,74,1,0]]) # our own input...
result    #you can use this model by using this particular code for any future prediction in new file...
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([23119.4579685])
